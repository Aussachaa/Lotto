# %%
import pandas as pd

# %%
path_excel = r"C:\Users\aussa\OneDrive\เดสก์ท็อป\personal\Lotto.xlsx"
df = pd.read_excel(path_excel, sheet_name="DB", usecols="D:L")
df
# Out:
#      รางวัลที่ 1  2 ตัวบน  3 ตัวบน  2 ตัวล่าง  3 ตัวหน้า_1  3 ตัวหน้า_2  \
# 0         367336       36      336         21           11          331
# 1         434503        3      503         89          839          975
# 2         518504        4      504         31           16          428
# 3         530593       93      593         42          194          364
# 4         205690       90      690         60          747          885
# ..           ...      ...      ...        ...          ...          ...
# 728      5984685       85      685          5          173          746
# 729      4791270       70      270         23          873          237
# 730      2669189       89      189         72          874          902
# 731      4043500        0      500         69          646          156
# 732      3670638       38      638         98          294          139
#
#      3 ตัวล่าง_1  3 ตัวล่าง_2       Date
# 0            421          618 2024-07-16
# ...
